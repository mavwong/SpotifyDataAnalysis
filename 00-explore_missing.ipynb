# %% [markdown]
# ## Library

# %%
import pandas as pd

from relative_path import PATH_DATA
from exploration_data import VisualizeMissing, CountMissingData

# %% [markdown]
# ## Standard

# %%
TRACK_DATA = PATH_DATA / "tracks.parquet"
ARTISTS_DATA = PATH_DATA / "artists.parquet"

# %% [markdown]
# ## Reading the Data

# %%
df_tracks = pd.read_parquet(TRACK_DATA)
df_artists = pd.read_parquet(ARTISTS_DATA)

# %% [markdown]
# ## Preprocess and Export Data

# %%
# Sort values and reset index
df_tracks.sort_values(by="popularity", ascending=False, inplace=True)
df_tracks.reset_index(drop=True, inplace=True)

df_artists.sort_values(by="popularity", ascending=False, inplace=True)
df_artists.reset_index(drop=True, inplace=True)

# %%
# Export Datas
df_tracks.to_parquet(TRACK_DATA)
df_artists.to_parquet(ARTISTS_DATA)

# %% [markdown]
# ## Explore with Pandas

# %%
print(df_tracks.shape)
print(df_artists.shape)
# Out:
# (586672, 20)
# (1104349, 5)

# %%
display(df_tracks.head(3))
display(df_artists.head(3))
# Out:
#                        id                                    name  popularity  \
# 0  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)         100
# 1  7lPN2DXiMsVn7XUKtOW1CS                         drivers license          99
# 2  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean          98
#
#    duration_ms  explicit                                       artists  \
# 0       198082         1  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 1       242014         1                            ['Olivia Rodrigo']
# 2       132780         0                               ['Masked Wolf']
#
#                                           id_artists release_date  \
# 0  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
# 1                         ['1McMsnEElThX1knmY4oliG']   2021-01-08
# 2                         ['1uU7g3DNSbsu0QjSEqZtEd']   2021-01-06
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.677   0.696    0    -6.181     1       0.1190         0.321
# 1         0.585   0.436   10    -8.761     1       0.0601         0.721
# 2         0.778   0.695    4    -6.865     0       0.0913         0.175
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000000     0.420    0.464   90.030               4
# 1          0.000013     0.105    0.132  143.874               4
# 2          0.000000     0.150    0.472  149.996               4
#                        id   followers  \
# 0  1uNFoZAHBGtllmzznpCI3s  44606973.0
# 1  3TVXtAsR1Inumwj472S9r4  54416812.0
# 2  4q3ewBCX7sLwd24euuV69X  32244734.0
#
#                                               genres           name  \
# 0           ['canadian pop', 'pop', 'post-teen pop']  Justin Bieber
# 1  ['canadian hip hop', 'canadian pop', 'hip hop'...          Drake
# 2              ['latin', 'reggaeton', 'trap latino']      Bad Bunny
#
#    popularity
# 0         100
# 1          98
# 2          98

# %%
print(df_tracks.index)
print(df_tracks.columns)
# Out:
# RangeIndex(start=0, stop=586672, step=1)
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
display(df_tracks.info())
display(df_artists.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104349 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB
# None

# %%
display(df_tracks.describe())
display(df_artists.describe())
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         0.343000       2.000000     -12.891000       0.000000
# 50%         0.549000       5.000000      -9.243000       1.000000
# 75%         0.748000       8.000000      -6.482000       1.000000
# max         1.000000      11.000000       5.376000       1.000000
#
#          speechiness   acousticness  instrumentalness       liveness  \
# count  586672.000000  586672.000000     586672.000000  586672.000000
# mean        0.104864       0.449863          0.113451       0.213935
# std         0.179893       0.348837          0.266868       0.184326
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.034000       0.096900          0.000000       0.098300
# 50%         0.044300       0.422000          0.000024       0.139000
# 75%         0.076300       0.785000          0.009550       0.278000
# max         0.971000       0.996000          1.000000       1.000000
#
#              valence          tempo  time_signature
# count  586672.000000  586672.000000   586672.000000
# mean        0.552292     118.464857        3.873382
# std         0.257671      29.764108        0.473162
# min         0.000000       0.000000        0.000000
# 25%         0.346000      95.600000        4.000000
# 50%         0.564000     117.384000        4.000000
# 75%         0.769000     136.321000        4.000000
# max         1.000000     246.381000        5.000000
#           followers    popularity
# count  1.104336e+06  1.104349e+06
# mean   1.074304e+04  9.083884e+00
# std    2.609554e+05  1.376310e+01
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+01  0.000000e+00
# 50%    5.900000e+01  2.000000e+00
# 75%    4.510000e+02  1.400000e+01
# max    7.890023e+07  1.000000e+02

# %%
display(df_tracks.value_counts())
display(df_artists.value_counts())
# Out:
# id                      name                                         popularity  duration_ms  explicit  artists                             id_artists                                            release_date  danceability  energy   key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence  tempo    time_signature
# 0004Uy71ku11n3LMpuyf59  24.11.94 - Wersja Akustyczna                 34          258907       0         ['Golden Life']                     ['3NyQ2NjqMjDtVSiEkXFW2r']                            2012-01-01    0.623         0.59900  6    -9.255    1     0.0255       0.1770        0.00148           0.0748    0.381    140.056  4                 1
# 57NqY1NP6lLkhWPMPGzl9T  Back to U                                    1           212125       0         ['ArtLec']                          ['2aqJXiggBZaS7nbLUMTMKo']                            2018-12-10    0.965         0.69000  11   -7.782    0     0.0944       0.1570        0.01500           0.1930    0.662    119.943  4                 1
# 57Nc8KTrSOGqgjxfGzqRP1  Wish You Were Here - Live at Knebworth 1990  36          283827       0         ['Pink Floyd']                      ['0k17h0D3J5VfsdmQ1iZtE9']                            2019-11-29    0.418         0.38200  7    -14.100   1     0.0304       0.3000        0.00207           0.7370    0.262    128.959  4                 1
# 57NjXhN5ORxGovxRxy08qn  Young & Free - Original One Remix            10          384760       0         ['Lee Rodriguez', 'African Dream']  ['7y0w0ynbJLuy9cSpJ9dWmb', '3aHhWPX1ok1pjdYuPmv3W3']  1995          0.669         0.69900  2    -19.834   1     0.0541       0.0103        0.91600           0.0640    0.965    120.027  4                 1
# 57NmDVSz11UQSpmtUK9Wmx  Soothe the Soul (Piano Instrumental)         53          88330        0         ['Nursery Rhymes 123']              ['47tuSUJMhsa3twW6wgKdIW']                            2016-01-26    0.619         0.00904  7    -31.013   1     0.0400       0.9960        0.95000           0.1320    0.682    70.535   3                 1
#                                                                                                                                                                                                                                                                                                                                                       ..
# 2VDYNUkhJi4lUlSTFGCBH5  Barco De Papel                               32          196400       0         ['Trio Parada Dura']                ['41fjoh5NjJhlDHYIUb9Hsk']                            1998-01-01    0.475         0.48500  5    -7.804    1     0.0271       0.5560        0.00000           0.1420    0.546    175.633  4                 1
# 2VDWYSr081eTN3US0x9mOH  The Race Is On                               15          106627       0         ['Jack Jones']                      ['6eVCRmRG2HcfL4yx77A9WK']                            1965-01-01    0.415         0.71900  6    -9.856    1     0.0395       0.3570        0.00000           0.0988    0.938    183.027  5                 1
# 2VDVRaYI5pQoq3cRIOk3CW  Szembogár                                    28          154360       0         ['Biorobot']                        ['7BOv2ycMYF2xLs71G3x5yn']                            2013-01-01    0.708         0.66000  9    -6.072    0     0.0640       0.5250        0.00000           0.3000    0.880    136.057  4                 1
# 2VDOt119cnJlsbFUBwKWHF  Pau De Arara                                 11          218667       0         ['Dizzy Gillespie']                 ['5RzjqfPS0Bu4bUMkyNNDpn']                            1962          0.475         0.65600  2    -12.119   0     0.0547       0.5900        0.02420           0.4790    0.686    142.638  4                 1
# 7zzuPsjj9L3M7ikqGmjN0D  A Long Time Ago                              42          139514       0         ['Jim Croce']                       ['1R6Hx1tJ2VOUyodEpC12xM']                            1972-04-01    0.526         0.43200  7    -11.197   1     0.0306       0.1410        0.00012           0.1340    0.793    114.362  4                 1
# Length: 586601, dtype: int64
# id                      followers  genres                                                                   name              popularity
# 0001K3ON4ACv7hte9Jlc6o  1.0        []                                                                       Chris             0             1
# 53pN11qa3C8Kg7bjFhn2II  4.0        []                                                                       Babyface Jay      0             1
# 53p1c0Fnb6srjMorsglFu7  1359.0     []                                                                       Wibutee           8             1
# 53p3F9PxpglQP5WcnbBvQ8  52.0       []                                                                       Walter Geiseking  2             1
# 53p5kiC47oEvG9E4VKDNl2  32836.0    ['classic polish pop', 'poezja spiewana', 'polish punk', 'sung poetry']  Jacek Kaczmarski  45            1
#                                                                                                                                            ..
# 2LZ25CJGU1im2UvzsjKDCY  159.0      []                                                                       Nadezhda Babkina  4             1
# 2LZ3j9FcPvimsXU44QgBWW  20568.0    ['pop peruano']                                                          Susan Ochoa       39            1
# 2LZ44MLhhXG2SlHhWUOGXg  1603.0     []                                                                       Alexia Gredy      15            1
# 2LZ8qA1M88bjqXVEVpoHXC  1.0        []                                                                       Bedana Dasi       0             1
# 7zzzZIHQepsP640xf9UDt4  167.0      []                                                                       Los Casal         1             1
# Length: 1104336, dtype: int64

# %% [markdown]
# ## Check Missing Values

# %%
vis_missing_tracks = VisualizeMissing(
    df_tracks, 
    "Tracks", 
    export_plot=True, 
    show_plot=False,
    process_zero=True, 
    process_null=True
)

# %%
vis_missing_tracks.Heatmap(show=True)

# %%
vis_missing_tracks.Matrix(show=True)

# %%
vis_missing_tracks.Bar(show=True)

# %%
vis_missing_artists = VisualizeMissing(
    df_artists, 
    "Artists", 
    export_plot=True, 
    show_plot=False,
    process_zero=True, 
    process_null=True
)

# %%
vis_missing_artists.Matrix(show=True)

# %%
vis_missing_artists.Heatmap(show=True)

# %%
vis_missing_artists.Bar(show=True)

# %% [markdown]
# ## Count of Missing Data Count and Percentage per Dataset

# %%
missing_tracks = CountMissingData(df_tracks).get()
missing_tracks
# Out:
#                   TotalMissing  Percent%
# explicit                560808  0.955914
# instrumentalness        205083  0.349570
# mode                    200174  0.341203
# key                      74950  0.127755
# popularity               44690  0.076175
# valence                    369  0.000629
# time_signature             337  0.000574
# speechiness                329  0.000561
# danceability               328  0.000559
# tempo                      328  0.000559
# name                        71  0.000121
# acousticness                66  0.000112
# liveness                    43  0.000073
# energy                      33  0.000056
# release_date                 0  0.000000
# loudness                     0  0.000000
# id_artists                   0  0.000000
# artists                      0  0.000000
# duration_ms                  0  0.000000
# id                           0  0.000000

# %%
missing_artists = CountMissingData(df_artists).get()
missing_artists
# Out:
#             TotalMissing  Percent%
# popularity        467416  0.423250
# followers          67888  0.061473
# id                     0  0.000000
# genres                 0  0.000000
# name                   0  0.000000
