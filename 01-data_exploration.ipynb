# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from relative_path import PATH_DATA, PATH_OUTPUT_DATA, PATH_OUTPUT_GRAPH, PATH_OUTPUT_PROF

from pandas import DataFrame, Series

# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
from data_processing import VisualizeMissing

# %% [markdown]
# ## Standard

# %%
TRACK_DATA = PATH_DATA / "tracks.parquet"
ARTISTS_DATA = PATH_DATA / "artists.parquet"

# %%
df_tracks = pd.read_parquet(TRACK_DATA)
df_artists = pd.read_parquet(ARTISTS_DATA)

# %%
vis_missing = VisualizeMissing(df_tracks, "Tracks_Data", export=True)

# %%
vis_missing.Bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 vis_missing.Bar()
#
# File ~/Desktop/Github/SpotifyDataAnalysis/data_processing.py:75, in VisualizeMissing.Bar(self)
#      72 fig.set(title=chart_name)
#      74 if self._export:
# ---> 75     plt.savefig(PATH_OUTPUT_GRAPH + fig_name)
#      76 return plt.show()
#
# TypeError: unsupported operand type(s) for +: 'PosixPath' and 'str'
